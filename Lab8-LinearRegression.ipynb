# %% [markdown]
# # Lab8: Lending Dataset – LinearRegression

# %% [markdown]
# #### Author: Dianna Hummel

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
# Out:
# C:\Users\Dianna\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ##### Step A

# %%
cols = ['ID', 'LoanAmt', 'IntRate', 'LoanTerm', 'Debt2Inc', 'Home', 'MonthlyInc', 'FICO-Range', 'RevCredBal', 'EmpLen']
loan_data = pd.read_csv("loansData.csv", header = None, names = cols)
loan_data = loan_data.set_index('ID')
loan_data.head(5)
# Out:
#        LoanAmt IntRate   LoanTerm Debt2Inc      Home  MonthlyInc FICO-Range  \
# ID
# 81174    20000   8.90%  36 months   14.90%  MORTGAGE     6541.67    735-739
# 99592    19200  12.12%  36 months   28.36%  MORTGAGE     4583.33    715-719
# 80059    35000  21.98%  60 months   23.81%  MORTGAGE    11500.00    690-694
# 33182    12000  11.71%  36 months   18.78%      RENT     3195.00    695-699
# 62403     6000  15.31%  36 months   20.05%       OWN     4891.67    670-674
#
#        RevCredBal    EmpLen
# ID
# 81174     14272.0  < 1 year
# 99592     11140.0   2 years
# 80059     21977.0   2 years
# 33182     14469.0   9 years
# 62403     10391.0   3 years

# %%
loan_data.dtypes
# Out:
# LoanAmt         int64
# IntRate        object
# LoanTerm       object
# Debt2Inc       object
# Home           object
# MonthlyInc    float64
# FICO-Range     object
# RevCredBal    float64
# EmpLen         object
# dtype: object

# %%
loan_data.shape
# Out:
# (1752, 9)

# %%
loan_data['Home'].value_counts()
# Out:
# RENT        844
# MORTGAGE    761
# OWN         147
# Name: Home, dtype: int64

# %%
loan_data['EmpLen'].value_counts()
# Out:
# 10+ years    453
# 2 years      175
# 3 years      166
# < 1 year     165
# 5 years      151
# 4 years      147
# 1 year       130
# 6 years      126
# 7 years      100
# 8 years       86
# 9 years       53
# Name: EmpLen, dtype: int64

# %%
loan_data['LoanTerm'].value_counts()
# Out:
# 36 months    1430
# 60 months     322
# Name: LoanTerm, dtype: int64

# %%
loan_data.describe()
# Out:
#             LoanAmt    MonthlyInc     RevCredBal
# count   1752.000000   1752.000000    1752.000000
# mean   11609.474886   5520.837854   13932.856164
# std     7443.034671   3186.290186   13708.658521
# min     1000.000000   1000.000000       0.000000
# 25%     6000.000000   3416.670000    5539.250000
# 50%    10000.000000   4833.330000   10738.500000
# 75%    15000.000000   6666.670000   17680.000000
# max    35000.000000  39583.330000  143151.000000

# %%
loan_data[loan_data.LoanAmt > loan_data.LoanAmt.mean()]
# Out:
#        LoanAmt IntRate   LoanTerm Debt2Inc      Home  MonthlyInc FICO-Range  \
# ID
# 81174    20000   8.90%  36 months   14.90%  MORTGAGE     6541.67    735-739
# 99592    19200  12.12%  36 months   28.36%  MORTGAGE     4583.33    715-719
# 80059    35000  21.98%  60 months   23.81%  MORTGAGE    11500.00    690-694
# 33182    12000  11.71%  36 months   18.78%      RENT     3195.00    695-699
# 76404    14675  14.33%  36 months   26.92%      RENT     3150.00    685-689
# 99483    30000  19.05%  60 months   21.25%  MORTGAGE     6250.00    695-699
# 24168    17400  11.99%  36 months   12.47%      RENT     6833.33    695-699
# 50182    14500   7.90%  36 months    4.85%  MORTGAGE     3958.33    760-764
# 87023    23850  21.00%  60 months   28.81%  MORTGAGE     5833.33    685-689
# 46120    14000  12.12%  36 months   14.93%  MORTGAGE    10583.33    685-689
# 94582    16000  15.80%  60 months   11.94%      RENT     5250.00    685-689
# 78862    20125   7.62%  36 months    4.29%  MORTGAGE     3750.00    830-834
# 95579    12725  11.14%  36 months   22.15%      RENT     4416.67    720-724
# 26822    15650  21.74%  36 months   13.86%      RENT     3700.00    660-664
# 81759    14000  12.12%  36 months   11.38%  MORTGAGE     4500.00    705-709
# 92046    32000  17.27%  60 months   15.61%      RENT     9250.00    700-704
# 88279    22250  21.49%  60 months   28.87%      RENT     4166.67    665-669
# 82406    16450  11.14%  36 months    7.57%      RENT     7500.00    725-729
# 96613    27575  14.33%  36 months   19.63%  MORTGAGE     5166.67    690-694
# 29283    12000  11.49%  36 months   12.85%      RENT     2708.33    705-709
# 99766    30000  10.16%  36 months   22.21%  MORTGAGE     8000.00    715-719
# 85893    13500  14.33%  36 months   31.70%      RENT     4166.67    680-684
# 44054    15000   9.91%  36 months    9.16%  MORTGAGE     4250.00    730-734
# 83768    12000  17.27%  36 months   14.86%       OWN     4583.33    665-669
# 67335    23675  17.77%  36 months   29.94%       OWN     6399.00    680-684
# 57080    12000  12.12%  36 months   18.62%      RENT     5833.33    690-694
# 30035    25000  16.49%  36 months   18.18%      RENT     6000.00    695-699
# 6987     12000  11.14%  36 months    2.37%  MORTGAGE    12500.00    735-739
# 41198    12000   6.62%  36 months   21.66%      RENT     5250.00    740-744
# 34122    15000  10.65%  36 months   16.15%  MORTGAGE     7083.33    720-724
# ...        ...     ...        ...      ...       ...         ...        ...
# 65776    15000  17.77%  36 months   18.24%  MORTGAGE     6000.00    670-674
# 73194    14575  19.05%  36 months   24.23%      RENT     3833.33    660-664
# 86479    14775  21.00%  60 months   27.59%  MORTGAGE     4473.33    675-679
# 83807    12300  13.11%  36 months    8.01%       OWN     3083.33    685-689
# 11723    20000  18.30%  60 months   15.91%  MORTGAGE     5833.00    690-694
# 22659    12000  12.68%  60 months    9.55%  MORTGAGE     9750.00    705-709
# 59011    13000   6.62%  36 months    5.95%  MORTGAGE    11666.67    750-754
# 92954    16200   8.90%  36 months   22.76%  MORTGAGE     4666.67    725-729
# 79820    25875  18.49%  60 months   13.83%  MORTGAGE     6000.00    715-719
# 13767    15000  19.04%  60 months   16.69%      RENT     5250.00    680-684
# 52759    25000   7.90%  36 months    1.73%      RENT     7500.00    765-769
# 98954    24000  16.29%  36 months   29.05%  MORTGAGE     5577.26    690-694
# 98510    21850  17.27%  60 months   21.94%       OWN     4166.67    710-714
# 68406    20000  14.09%  36 months    9.16%  MORTGAGE    19583.33    710-714
# 43056    15000   7.90%  36 months   22.24%      RENT     2666.67    735-739
# 45519    19000  13.67%  36 months   15.12%      RENT     3544.67    685-689
# 92038    22750  22.47%  60 months   29.03%       OWN     4333.33    670-674
# 84265    20000  22.95%  60 months    7.10%      RENT     6750.00    665-669
# 80231    19000   7.90%  36 months    9.76%  MORTGAGE     5166.67    770-774
# 85216    17500   8.90%  36 months   10.94%  MORTGAGE    25000.00    730-734
# 38247    20000  11.71%  36 months    9.58%  MORTGAGE     5416.67    725-729
# 91245    16200  15.80%  60 months    7.92%  MORTGAGE     4833.33    680-684
# 63051    27000   6.62%  36 months   12.21%  MORTGAGE     9250.00    810-814
# 68628    15875  14.33%  36 months   17.44%  MORTGAGE     3416.67    675-679
# 98758    15000  10.16%  36 months   28.28%  MORTGAGE     6666.67    690-694
# 52330    15000  19.99%  36 months   18.05%      RENT     8000.00    660-664
# 48243    17000  15.81%  36 months   17.01%      RENT     3833.33    685-689
# 63256    19075  18.75%  36 months   15.23%      RENT     5166.67    670-674
# 74047    30000  23.28%  60 months   12.10%  MORTGAGE     7083.33    675-679
# 65882    16000  14.09%  60 months   21.54%       OWN     8903.25    740-744
#
#        RevCredBal     EmpLen
# ID
# 81174     14272.0   < 1 year
# 99592     11140.0    2 years
# 80059     21977.0    2 years
# 33182     14469.0    9 years
# 76404      7246.0    8 years
# 99483     34927.0    6 years
# 24168     26587.0    7 years
# 50182      9598.0    4 years
# 87023     25968.0    9 years
# 46120     35457.0    2 years
# 94582       154.0    3 years
# 78862     73952.0     1 year
# 95579      4079.0    3 years
# 26822     10605.0    4 years
# 81759     18583.0    5 years
# 92046     32566.0    2 years
# 88279     14107.0    9 years
# 82406      2928.0     1 year
# 96613      8720.0  10+ years
# 29283     12150.0   < 1 year
# 99766     33218.0  10+ years
# 85893     31168.0     1 year
# 44054     11615.0  10+ years
# 83768      9145.0  10+ years
# 67335     21920.0  10+ years
# 57080     18838.0  10+ years
# 30035     10630.0    7 years
# 6987      10944.0    5 years
# 41198     20639.0   < 1 year
# 34122       338.0    9 years
# ...           ...        ...
# 65776     14513.0  10+ years
# 73194     13753.0  10+ years
# 86479     33869.0  10+ years
# 83807      6162.0    9 years
# 11723     16140.0  10+ years
# 22659     17259.0    8 years
# 59011     11451.0    7 years
# 92954     15503.0    7 years
# 79820     12316.0  10+ years
# 13767      8615.0    2 years
# 52759      4329.0    4 years
# 98954     13393.0    2 years
# 98510     20971.0    4 years
# 68406     31277.0    7 years
# 43056     11105.0   < 1 year
# 45519      9503.0   < 1 year
# 92038     11567.0     1 year
# 84265     16104.0    7 years
# 80231     43617.0  10+ years
# 85216     34545.0    6 years
# 38247     18267.0    4 years
# 91245     12313.0  10+ years
# 63051      4211.0    5 years
# 68628     15891.0    2 years
# 98758     14880.0  10+ years
# 52330     45976.0    2 years
# 48243     15484.0    6 years
# 63256     13749.0  10+ years
# 74047     17969.0  10+ years
# 65882     18898.0  10+ years
#
# [737 rows x 9 columns]

# %%
loan_data[loan_data.MonthlyInc < loan_data.MonthlyInc.std()]
# Out:
#        LoanAmt IntRate   LoanTerm Debt2Inc      Home  MonthlyInc FICO-Range  \
# ID
# 48808    10000   7.90%  36 months   26.09%      RENT     2916.67    720-724
# 76404    14675  14.33%  36 months   26.92%      RENT     3150.00    685-689
# 44987    10000   9.76%  36 months    7.13%      RENT     2733.33    730-734
# 2238      8000  14.42%  36 months   24.63%      RENT     2964.17    675-679
# 65278     8000  15.31%  36 months   15.46%  MORTGAGE     2916.67    675-679
# 98029     3200  17.27%  36 months    8.36%  MORTGAGE     2500.00    670-674
# 14754     3000  10.38%  36 months   15.21%      RENT     3083.33    710-714
# 17143     2500  12.98%  36 months   16.45%      RENT     1100.00    670-674
# 27486     6000   9.99%  36 months    7.50%  MORTGAGE     2625.00    715-719
# 29283    12000  11.49%  36 months   12.85%      RENT     2708.33    705-709
# 9664      4500   6.76%  36 months   14.74%  MORTGAGE     2666.67    790-794
# 1494      1600  10.83%  36 months    5.36%      RENT     2427.00    700-704
# 61703    10000  17.77%  36 months   30.40%       OWN     2500.00    665-669
# 95096     7925  16.29%  36 months   21.25%      RENT     2000.00    665-669
# 13216     6000  14.35%  36 months   14.08%  MORTGAGE     2500.00    675-679
# 82476    10000  14.09%  36 months   10.59%      RENT     2916.67    690-694
# 48662     8800  13.11%  36 months   16.73%      RENT     3150.25    700-704
# 92773     8000  13.11%  36 months   19.01%      RENT     2625.00    725-729
# 81950    11625  14.33%  36 months   22.84%  MORTGAGE     2833.33    705-709
# 22858     8400   6.92%  36 months   13.30%      RENT     3000.00    745-749
# 87504     2800  10.16%  36 months      12%      RENT     2083.33    695-699
# 92105     7750  16.29%  36 months   26.74%  MORTGAGE     2916.67    680-684
# 59387     4500   8.90%  36 months   18.18%      RENT     2166.67    700-704
# 96988    10000  13.11%  36 months    7.56%      RENT     2500.00    685-689
# 97954     4375  19.05%  36 months    9.09%      RENT     2916.67    670-674
# 63340     7000  18.49%  36 months   18.90%  MORTGAGE     2000.00    660-664
# 64690     6000  14.09%  36 months   22.50%      RENT     2666.67    670-674
# 78519     4800  13.11%  36 months    4.61%      RENT     2666.67    690-694
# 78856     8325  17.77%  36 months   20.75%      RENT     2000.00    665-669
# 98671     4750  22.47%  36 months   24.45%      RENT     1333.33    665-669
# ...        ...     ...        ...      ...       ...         ...        ...
# 43610     5000   7.51%  36 months   11.40%      RENT     1666.67    750-754
# 87119     4000  14.33%  36 months   22.74%      RENT     1666.67    665-669
# 28368     5000   8.49%  36 months   22.53%  MORTGAGE     3000.00    720-724
# 13652     4800  10.75%  36 months   22.63%      RENT     1750.00    710-714
# 36084     5300   7.90%  36 months    9.67%      RENT     1945.00    760-764
# 45644    10000   9.76%  36 months   18.31%      RENT     2916.67    725-729
# 88584    10000  19.72%  36 months   27.53%  MORTGAGE     2916.67    665-669
# 61697     8875  15.31%  36 months   30.15%      RENT     2291.67    680-684
# 64440    10625  17.77%  36 months   22.10%       OWN     2633.33    660-664
# 33275     4400  12.42%  36 months      19%      RENT     2000.00    715-719
# 36803     3000  11.71%  36 months   16.80%      RENT     3083.33    695-699
# 61587     6250  14.33%  36 months   20.40%  MORTGAGE     1750.00    675-679
# 80404     7750  20.49%  36 months       9%  MORTGAGE     2000.00    660-664
# 11625     4000  11.49%  36 months    4.16%      RENT     2666.67    720-724
# 62824    10375  14.33%  36 months   26.42%      RENT     2479.17    680-684
# 22573     9800  14.91%  60 months   12.89%  MORTGAGE     2708.33    690-694
# 47097     7200   7.90%  36 months   12.13%      RENT     2333.33    725-729
# 92717     7125   7.62%  36 months    7.96%       OWN     2500.00    805-809
# 11626     4500   7.51%  36 months   13.90%  MORTGAGE     3000.00    765-769
# 54073     7425   9.76%  36 months    7.32%  MORTGAGE     2500.00    705-709
# 39492    10000  11.71%  36 months    8.69%      RENT     2750.00    695-699
# 70427     8450  18.49%  36 months   21.98%       OWN     2083.33    660-664
# 12976     2000  11.49%  36 months    2.44%      RENT     2500.00    700-704
# 6711      8000  20.52%  36 months    8.12%      RENT     2500.00    675-679
# 24353     9500  14.79%  60 months   12.13%      RENT     3000.00    710-714
# 83807    12300  13.11%  36 months    8.01%       OWN     3083.33    685-689
# 3508      2000  16.00%  36 months    2.55%      RENT     2000.00    665-669
# 43056    15000   7.90%  36 months   22.24%      RENT     2666.67    735-739
# 45836     7000  17.27%  36 months   18.38%       OWN     2464.37    665-669
# 55610    10000  13.99%  36 months    4.89%  MORTGAGE     2166.67    680-684
#
#        RevCredBal     EmpLen
# ID
# 48808     15957.0  10+ years
# 76404      7246.0    8 years
# 44987      6112.0    3 years
# 2238       8928.0    6 years
# 65278      7152.0    5 years
# 98029      6619.0    3 years
# 14754      3098.0    2 years
# 17143      5019.0    4 years
# 27486      5167.0  10+ years
# 29283     12150.0   < 1 year
# 9664       2705.0    7 years
# 1494       7020.0    3 years
# 61703      8379.0    8 years
# 95096      7840.0    6 years
# 13216      3621.0   < 1 year
# 82476     10390.0   < 1 year
# 48662     14266.0    4 years
# 92773      7554.0    5 years
# 81950     27411.0    8 years
# 22858      6998.0     1 year
# 87504      7261.0   < 1 year
# 92105     17102.0    5 years
# 59387      5361.0    4 years
# 96988     10906.0    7 years
# 97954      6944.0    6 years
# 63340      7315.0     1 year
# 64690      5955.0  10+ years
# 78519      7911.0   < 1 year
# 78856      7676.0   < 1 year
# 98671      4752.0   < 1 year
# ...           ...        ...
# 43610      7968.0  10+ years
# 87119       278.0    3 years
# 28368      3388.0  10+ years
# 13652     11234.0    5 years
# 36084      5360.0    8 years
# 45644      5670.0  10+ years
# 88584     11506.0  10+ years
# 61697     11798.0    2 years
# 64440     12156.0   < 1 year
# 33275      2411.0    5 years
# 36803       413.0    2 years
# 61587      7845.0    4 years
# 80404      5399.0    5 years
# 11625      3239.0     1 year
# 62824     13411.0    5 years
# 22573      8111.0    3 years
# 47097      6262.0    2 years
# 92717       577.0     1 year
# 11626       387.0   < 1 year
# 54073      5045.0    4 years
# 39492      6621.0    3 years
# 70427      7352.0    3 years
# 12976        67.0    2 years
# 6711       7327.0   < 1 year
# 24353     14227.0    3 years
# 83807      6162.0    9 years
# 3508          0.0   < 1 year
# 43056     11105.0   < 1 year
# 45836      7089.0    3 years
# 55610      4544.0  10+ years
#
# [355 rows x 9 columns]

# %% [markdown]
# ##### Step B

# %%
ir = loan_data['IntRate'].values
ir[:5]
# Out:
# array(['8.90%', '12.12%', '21.98%', '11.71%', '15.31%'], dtype=object)

# %%
nopct = [x[:-1] for x in ir]
nopct[:5]
# Out:
# ['8.90', '12.12', '21.98', '11.71', '15.31']

# %%
irFloat = [float(x) for x in nopct]
irFloat[:5]
# Out:
# [8.9, 12.12, 21.98, 11.71, 15.31]

# %%
loan_data['IntRate'] = irFloat
loan_data['IntRate'].dtype
# Out:
# dtype('float64')

# %%
di = loan_data['Debt2Inc'].values
di[:5]
# Out:
# array(['14.90%', '28.36%', '23.81%', '18.78%', '20.05%'], dtype=object)

# %%
nop = [x[:-1] for x in di]
nop[:5]
# Out:
# ['14.90', '28.36', '23.81', '18.78', '20.05']

# %%
diFloat = [float(x) for x in nop]
diFloat[:5]
# Out:
# [14.9, 28.36, 23.81, 18.78, 20.05]

# %%
loan_data['Debt2Inc'] = diFloat
loan_data['Debt2Inc'].dtype
# Out:
# dtype('float64')

# %%
FICO_str = loan_data['FICO-Range'].values
FICO_str[:5]
# Out:
# array(['735-739', '715-719', '690-694', '695-699', '670-674'], dtype=object)

# %%
scores = [f_str.split('-') for f_str in FICO_str]
scores[:5]
# Out:
# [['735', '739'],
#  ['715', '719'],
#  ['690', '694'],
#  ['695', '699'],
#  ['670', '674']]

# %%
int_scores = [[int(sc) for sc in inner] for inner in scores]
int_scores[:5]
# Out:
# [[735, 739], [715, 719], [690, 694], [695, 699], [670, 674]]

# %%
meanFICO = [int((sc[0] + sc[1]) / 2) for sc in int_scores]
meanFICO[:5]
# Out:
# [737, 717, 692, 697, 672]

# %%
loan_data['FICO'] = meanFICO
loan_data = loan_data.drop('FICO-Range', axis=1)
loan_data.columns
# Out:
# Index(['LoanAmt', 'IntRate', 'LoanTerm', 'Debt2Inc', 'Home', 'MonthlyInc',
#        'RevCredBal', 'EmpLen', 'FICO'],
#       dtype='object')

# %%
lt_str = loan_data['LoanTerm'].values
lt_str[:5]
# Out:
# array(['36 months', '36 months', '60 months', '36 months', '36 months'], dtype=object)

# %%
term = [lt.split(' ') for lt in lt_str]
term[:5]
# Out:
# [['36', 'months'],
#  ['36', 'months'],
#  ['60', 'months'],
#  ['36', 'months'],
#  ['36', 'months']]

# %%
months = [int(x[0]) for x in term]
months[:5]
# Out:
# [36, 36, 60, 36, 36]

# %%
months = [0 if m == 36 else 1 for m in months]
months[:5]
# Out:
# [0, 0, 1, 0, 0]

# %%
loan_data['LoanTerm'] = months
loan_data['LoanTerm'].head(5)
# Out:
# ID
# 81174    0
# 99592    0
# 80059    1
# 33182    0
# 62403    0
# Name: LoanTerm, dtype: int64

# %%
loan_data.loc[loan_data.Home == 'MORTGAGE','Home'] = 'MORT'
loan_data['Home'].head(5)
# Out:
# ID
# 81174    MORT
# 99592    MORT
# 80059    MORT
# 33182    RENT
# 62403     OWN
# Name: Home, dtype: object

# %%
years = loan_data['EmpLen'].values
years[:5]
# Out:
# array(['< 1 year', '2 years', '2 years', '9 years', '3 years'], dtype=object)

# %%
year_list = [y.split(' ') for y in years]
year_list[:5]
# Out:
# [['<', '1', 'year'],
#  ['2', 'years'],
#  ['2', 'years'],
#  ['9', 'years'],
#  ['3', 'years']]

# %%
num_str = [x[0] for x in year_list]
num_str[:5]
# Out:
# ['<', '2', '2', '9', '3']

# %%
emp_len = []
for num in num_str:
    if num == '<':
        emp_len.append(0)
    elif num == '10+':
         emp_len.append(10)
    else:
         emp_len.append(int (num))
emp_len[:5]
# Out:
# [0, 2, 2, 9, 3]

# %%
loan_data['EmpLen'] = emp_len
loan_data['EmpLen'].head()
# Out:
# ID
# 81174    0
# 99592    2
# 80059    2
# 33182    9
# 62403    3
# Name: EmpLen, dtype: int64

# %%
loan_data.head(5)
# Out:
#        LoanAmt  IntRate  LoanTerm  Debt2Inc  Home  MonthlyInc  RevCredBal  \
# ID
# 81174    20000     8.90         0     14.90  MORT     6541.67     14272.0
# 99592    19200    12.12         0     28.36  MORT     4583.33     11140.0
# 80059    35000    21.98         1     23.81  MORT    11500.00     21977.0
# 33182    12000    11.71         0     18.78  RENT     3195.00     14469.0
# 62403     6000    15.31         0     20.05   OWN     4891.67     10391.0
#
#        EmpLen  FICO
# ID
# 81174       0   737
# 99592       2   717
# 80059       2   692
# 33182       9   697
# 62403       3   672

# %% [markdown]
# ##### Step C

# %%
home_dum = pd.get_dummies(loan_data['Home'],prefix='Home_')

# %%
loan_X1 = loan_data[['LoanAmt','LoanTerm', 'Debt2Inc']].join (home_dum)
loan_X2 = loan_data[['MonthlyInc','RevCredBal','FICO', 'EmpLen']]
loan_Y = loan_data[['IntRate']]
loan_data = pd.concat([loan_Y, loan_X1, loan_X2], axis=1)
loan_data.head()
# Out:
#        IntRate  LoanAmt  LoanTerm  Debt2Inc  Home__MORT  Home__OWN  \
# ID
# 81174     8.90    20000         0     14.90           1          0
# 99592    12.12    19200         0     28.36           1          0
# 80059    21.98    35000         1     23.81           1          0
# 33182    11.71    12000         0     18.78           0          0
# 62403    15.31     6000         0     20.05           0          1
#
#        Home__RENT  MonthlyInc  RevCredBal  FICO  EmpLen
# ID
# 81174           0     6541.67     14272.0   737       0
# 99592           0     4583.33     11140.0   717       2
# 80059           0    11500.00     21977.0   692       2
# 33182           1     3195.00     14469.0   697       9
# 62403           0     4891.67     10391.0   672       3

# %% [markdown]
# ##### Step D

# %%
loan_corr = loan_data.corr()
loan_corr
# Out:
#              IntRate   LoanAmt  LoanTerm  Debt2Inc  Home__MORT  Home__OWN  \
# IntRate     1.000000  0.308321  0.414420  0.157653   -0.086886  -0.007368
# LoanAmt     0.308321  1.000000  0.370207  0.083909    0.151616  -0.049427
# LoanTerm    0.414420  0.370207  1.000000  0.015259    0.047973  -0.021353
# Debt2Inc    0.157653  0.083909  0.015259  1.000000   -0.003505   0.023173
# Home__MORT -0.086886  0.151616  0.047973 -0.003505    1.000000  -0.265202
# Home__OWN  -0.007368 -0.049427 -0.021353  0.023173   -0.265202   1.000000
# Home__RENT  0.090279 -0.122979 -0.035742 -0.009381   -0.844858  -0.291776
# MonthlyInc  0.018718  0.439503  0.081958 -0.178562    0.250199  -0.092213
# RevCredBal  0.078770  0.364792  0.093702  0.219052    0.208887  -0.052714
# FICO       -0.733519  0.060730 -0.011196 -0.210367    0.131209   0.003564
# EmpLen      0.039927  0.157921  0.060672  0.019866    0.243583  -0.024375
#
#             Home__RENT  MonthlyInc  RevCredBal      FICO    EmpLen
# IntRate       0.090279    0.018718    0.078770 -0.733519  0.039927
# LoanAmt      -0.122979    0.439503    0.364792  0.060730  0.157921
# LoanTerm     -0.035742    0.081958    0.093702 -0.011196  0.060672
# Debt2Inc     -0.009381   -0.178562    0.219052 -0.210367  0.019866
# Home__MORT   -0.844858    0.250199    0.208887  0.131209  0.243583
# Home__OWN    -0.291776   -0.092213   -0.052714  0.003564 -0.024375
# Home__RENT    1.000000   -0.197034   -0.177969 -0.132138 -0.228111
# MonthlyInc   -0.197034    1.000000    0.432443  0.114587  0.096702
# RevCredBal   -0.177969    0.432443    1.000000  0.003040  0.139835
# FICO         -0.132138    0.114587    0.003040  1.000000  0.020892
# EmpLen       -0.228111    0.096702    0.139835  0.020892  1.000000

# %%
grps = ['NegStrong','NegMedium','Weak','PosMedium','PosStrong']
cols = ['IntRate', 'LoanAmt', 'LoanTerm', 'Debt2Inc', 'Home__MORT','Home__OWN','Home__RENT', 'MonthlyInc', 'RevCredBal', 'FICO', 'EmpLen']
for col in cols:
    loan_corr[col] = pd.cut (loan_corr[col],(-1,-0.7,-0.3,0.3,0.7,1), labels = grps)
loan_corr
# Out:
#               IntRate    LoanAmt   LoanTerm   Debt2Inc Home__MORT  Home__OWN  \
# IntRate     PosStrong  PosMedium  PosMedium       Weak       Weak       Weak
# LoanAmt     PosMedium  PosStrong  PosMedium       Weak       Weak       Weak
# LoanTerm    PosMedium  PosMedium  PosStrong       Weak       Weak       Weak
# Debt2Inc         Weak       Weak       Weak  PosStrong       Weak       Weak
# Home__MORT       Weak       Weak       Weak       Weak  PosStrong       Weak
# Home__OWN        Weak       Weak       Weak       Weak       Weak  PosStrong
# Home__RENT       Weak       Weak       Weak       Weak  NegStrong       Weak
# MonthlyInc       Weak  PosMedium       Weak       Weak       Weak       Weak
# RevCredBal       Weak  PosMedium       Weak       Weak       Weak       Weak
# FICO        NegStrong       Weak       Weak       Weak       Weak       Weak
# EmpLen           Weak       Weak       Weak       Weak       Weak       Weak
#
#            Home__RENT MonthlyInc RevCredBal       FICO     EmpLen
# IntRate          Weak       Weak       Weak  NegStrong       Weak
# LoanAmt          Weak  PosMedium  PosMedium       Weak       Weak
# LoanTerm         Weak       Weak       Weak       Weak       Weak
# Debt2Inc         Weak       Weak       Weak       Weak       Weak
# Home__MORT  NegStrong       Weak       Weak       Weak       Weak
# Home__OWN        Weak       Weak       Weak       Weak       Weak
# Home__RENT  PosStrong       Weak       Weak       Weak       Weak
# MonthlyInc       Weak  PosStrong  PosMedium       Weak       Weak
# RevCredBal       Weak  PosMedium  PosStrong       Weak       Weak
# FICO             Weak       Weak       Weak  PosStrong       Weak
# EmpLen           Weak       Weak       Weak       Weak  PosStrong

# %%
loan_data = loan_data.drop(['Debt2Inc', 'Home__MORT', 'Home__OWN','Home__RENT','EmpLen'], axis=1)
loan_data.head()
# Out:
#        IntRate  LoanAmt  LoanTerm  MonthlyInc  RevCredBal  FICO
# ID
# 81174     8.90    20000         0     6541.67     14272.0   737
# 99592    12.12    19200         0     4583.33     11140.0   717
# 80059    21.98    35000         1    11500.00     21977.0   692
# 33182    11.71    12000         0     3195.00     14469.0   697
# 62403    15.31     6000         0     4891.67     10391.0   672

# %%
sns.pairplot (loan_data, hue = 'LoanTerm', size=2.5)

# %% [markdown]
# ##### Step E

# %%
Y = loan_data ['IntRate']
Y.head()
# Out:
# ID
# 81174     8.90
# 99592    12.12
# 80059    21.98
# 33182    11.71
# 62403    15.31
# Name: IntRate, dtype: float64

# %%
X = loan_data.drop (['IntRate'], axis=1)
X.head()
# Out:
#        LoanAmt  LoanTerm  MonthlyInc  RevCredBal  FICO
# ID
# 81174    20000         0     6541.67     14272.0   737
# 99592    19200         0     4583.33     11140.0   717
# 80059    35000         1    11500.00     21977.0   692
# 33182    12000         0     3195.00     14469.0   697
# 62403     6000         0     4891.67     10391.0   672

# %%
sc = StandardScaler()

# %%
sc.fit (X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_std = sc.transform(X)
X_std[:5]
# Out:
# array([[ 1.1276208 , -0.4745259 ,  0.32047414,  0.02474645,  0.97751917],
#        [ 1.02010707, -0.4745259 , -0.29431579, -0.20378752,  0.37469848],
#        [ 3.14350321,  2.10736655,  1.87706358,  0.58696046, -0.37882739],
#        [ 0.05248351, -0.4745259 , -0.73016008,  0.03912104, -0.22812221],
#        [-0.75386945, -0.4745259 , -0.19751732, -0.25844012, -0.98164808]])

# %% [markdown]
# ##### Step F

# %%
X_std0 = sm.add_constant (X_std)

# %%
loan_model0 = sm.OLS (Y, X_std0)

# %%
loan_model0 = loan_model0.fit()

# %%
loan_model0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                IntRate   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     1061.
# Date:                Thu, 19 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:45:20   Log-Likelihood:                -3777.3
# No. Observations:                1752   AIC:                             7567.
# Df Residuals:                    1746   BIC:                             7599.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.1208      0.050    262.351      0.000      13.023      13.219
# x1             1.0841      0.061     17.664      0.000       0.964       1.204
# x2             1.3246      0.054     24.474      0.000       1.218       1.431
# x3            -0.0876      0.059     -1.474      0.141      -0.204       0.029
# x4            -0.1414      0.057     -2.485      0.013      -0.253      -0.030
# x5            -3.1211      0.050    -61.870      0.000      -3.220      -3.022
# ==============================================================================
# Omnibus:                      109.642   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              183.557
# Skew:                           0.479   Prob(JB):                     1.38e-40
# Kurtosis:                       4.264   Cond. No.                         2.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_std1 = np.delete (X_std, [2], axis=1)
X_std1[:5]
# Out:
# array([[ 1.1276208 , -0.4745259 ,  0.02474645,  0.97751917],
#        [ 1.02010707, -0.4745259 , -0.20378752,  0.37469848],
#        [ 3.14350321,  2.10736655,  0.58696046, -0.37882739],
#        [ 0.05248351, -0.4745259 ,  0.03912104, -0.22812221],
#        [-0.75386945, -0.4745259 , -0.25844012, -0.98164808]])

# %%
X_std2 = sm.add_constant (X_std1)
loan_model1 = sm.OLS (Y, X_std2)
loan_model1 = loan_model1.fit()
loan_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                IntRate   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     1325.
# Date:                Thu, 19 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:45:20   Log-Likelihood:                -3778.4
# No. Observations:                1752   AIC:                             7567.
# Df Residuals:                    1747   BIC:                             7594.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.1208      0.050    262.263      0.000      13.023      13.219
# x1             1.0536      0.058     18.226      0.000       0.940       1.167
# x2             1.3311      0.054     24.671      0.000       1.225       1.437
# x3            -0.1688      0.054     -3.137      0.002      -0.274      -0.063
# x4            -3.1291      0.050    -62.373      0.000      -3.227      -3.031
# ==============================================================================
# Omnibus:                      110.149   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              188.145
# Skew:                           0.474   Prob(JB):                     1.40e-41
# Kurtosis:                       4.295   Cond. No.                         1.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_std3 = np.delete (X_std, [3], axis=1)
X_std3[:5]
# Out:
# array([[ 1.1276208 , -0.4745259 ,  0.32047414,  0.97751917],
#        [ 1.02010707, -0.4745259 , -0.29431579,  0.37469848],
#        [ 3.14350321,  2.10736655,  1.87706358, -0.37882739],
#        [ 0.05248351, -0.4745259 , -0.73016008, -0.22812221],
#        [-0.75386945, -0.4745259 , -0.19751732, -0.98164808]])

# %%
X_std4 = sm.add_constant (X_std3)
loan_model2 = sm.OLS (Y, X_std4)
loan_model2 = loan_model2.fit()
loan_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                IntRate   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     1321.
# Date:                Thu, 19 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:45:20   Log-Likelihood:                -3780.4
# No. Observations:                1752   AIC:                             7571.
# Df Residuals:                    1747   BIC:                             7598.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.1208      0.050    261.963      0.000      13.023      13.219
# x1             1.0524      0.060     17.505      0.000       0.934       1.170
# x2             1.3271      0.054     24.489      0.000       1.221       1.433
# x3            -0.1358      0.056     -2.414      0.016      -0.246      -0.025
# x4            -3.1140      0.050    -61.736      0.000      -3.213      -3.015
# ==============================================================================
# Omnibus:                      105.111   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.175
# Skew:                           0.468   Prob(JB):                     2.49e-38
# Kurtosis:                       4.223   Cond. No.                         1.88
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
pca = PCA (n_components=4)
X_std_pc4 = pca.fit_transform (X_std)
np.cumsum (np.round (pca.explained_variance_ratio_, decimals=4)*100)
# Out:
# array([ 38.88,  59.86,  79.28,  90.73])

# %%
X_std_pc4 = sm.add_constant (X_std_pc4)
loan_model3 = sm.OLS (Y, X_std_pc4)
loan_model3 = loan_model3.fit()
loan_model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                IntRate   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     1321.
# Date:                Thu, 19 Oct 2017   Prob (F-statistic):               0.00
# Time:                        13:45:20   Log-Likelihood:                -3780.3
# No. Observations:                1752   AIC:                             7571.
# Df Residuals:                    1747   BIC:                             7598.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.1208      0.050    261.975      0.000      13.023      13.219
# x1             0.6242      0.036     17.377      0.000       0.554       0.695
# x2            -3.1363      0.049    -64.139      0.000      -3.232      -3.040
# x3             1.4006      0.051     27.553      0.000       1.301       1.500
# x4            -0.6918      0.066    -10.448      0.000      -0.822      -0.562
# ==============================================================================
# Omnibus:                      108.354   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              182.499
# Skew:                           0.473   Prob(JB):                     2.35e-40
# Kurtosis:                       4.268   Cond. No.                         1.84
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ##### Step G

# %%
X_std1 = np.delete(X_std, [2], axis=1)
X_std1[:5]
# Out:
# array([[ 1.1276208 , -0.4745259 ,  0.02474645,  0.97751917],
#        [ 1.02010707, -0.4745259 , -0.20378752,  0.37469848],
#        [ 3.14350321,  2.10736655,  0.58696046, -0.37882739],
#        [ 0.05248351, -0.4745259 ,  0.03912104, -0.22812221],
#        [-0.75386945, -0.4745259 , -0.25844012, -0.98164808]])

# %%
Y[:5]
# Out:
# ID
# 81174     8.90
# 99592    12.12
# 80059    21.98
# 33182    11.71
# 62403    15.31
# Name: IntRate, dtype: float64

# %%
scores_list = []
for rep in range(128):
    lm = linear_model.LinearRegression()
    scores = cross_val_score(lm, X_std1, Y, cv=8)
    scores_list.append(scores.mean())
print ('Mean Score:', sum(scores_list)/len (scores_list))
# Out:
# Mean Score: 0.748333003591

# %%
lm = linear_model.LinearRegression()
X_train, X_test, Y_train, Y_test = train_test_split(X_std1,
Y, random_state=33,test_size=0.2)
model = lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)

# %%
print ('Score:', model.score(X_test, Y_test))
# Out:
# Score: 0.783473564144

# %%
predictions[:5]
# Out:
# array([ 15.69757892,   6.7846537 ,  13.53159933,   7.5077869 ,  13.94582737])

# %%
Y_test[:5]
# Out:
# ID
# 68628    14.33
# 23644     5.79
# 55177    13.67
# 26290     8.90
# 24846    13.49
# Name: IntRate, dtype: float64

# %%
plt.scatter(Y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
